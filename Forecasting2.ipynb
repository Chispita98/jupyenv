# %%
library(fpp2)

# %%
data<-read.csv("pg76.csv",header=TRUE)
tsData<- ts(data[2:45,2],start=c(2016,1),frequency=12)

# %%
tsData %>% stl(s.window='periodic') %>% seasadj() -> eeadj
autoplot(eeadj)
# Out:
# plot without title

# %%
eeadj %>% diff() %>% ggtsdisplay(main="")
# Out:
# plot without title

# %%
(fit <- Arima(eeadj, order=c(0,1,1)))
# Out:
# Series: eeadj
# ARIMA(0,1,1)
#
# Coefficients:
#           ma1
#       -0.3941
# s.e.   0.1243
#
# sigma^2 estimated as 1754010:  log likelihood=-369.71
# AIC=743.41   AICc=743.71   BIC=746.94

# %%
checkresiduals(fit)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(0,1,1)
# Q* = 9.7424, df = 8, p-value = 0.2836
#
# Model df: 1.   Total lags used: 9
# plot without title

# %%
autoplot(forecast(fit, h=12))
# Out:
# plot without title
